# %% [markdown]
# <a href="https://colab.research.google.com/github/Htar-Su/_HTAR_Deep_RL_Course_by_Hugging_Face/blob/main/2_DeepRL_A2C_Robotic_Arm_ReachDense_and_PickandPlace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 6: Advantage Actor Critic (A2C) using Robotics Simulations with Panda-Gym 🤖
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/thumbnail.png"  alt="Thumbnail"/>
#
# In this notebook, you'll learn to use A2C with [Panda-Gym](https://github.com/qgallouedec/panda-gym). You're going **to train a robotic arm** (Franka Emika Panda robot) to perform a task:
#
# - `Reach`: the robot must place its end-effector at a target position.
#
# After that, you'll be able **to train in other robotics tasks**.

# %% [markdown]
# ### 🎮 Environments:
#
# - [Panda-Gym](https://github.com/qgallouedec/panda-gym)
#
# ###📚 RL-Library:
#
# - [Stable-Baselines3](https://stable-baselines3.readthedocs.io/)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the GitHub Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Be able to use **Panda-Gym**, the environment library.
# - Be able to **train robots using A2C**.
# - Understand why **we need to normalize the input**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from the Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>
#
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 Study [Actor-Critic methods by reading Unit 6](https://huggingface.co/deep-rl-course/unit6/introduction) 🤗

# %% [markdown]
# # Let's train our first robots 🤖

# %% [markdown]
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process),  you need to push your trained model to the Hub and get the following results:
#
# - `PandaReachDense-v3` get a result of >= -3.5.
#
# To find your result, go to the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ### Install dependencies 🔽
#
# The first step is to install the dependencies, we’ll install multiple ones:
# - `gymnasium`
# - `panda-gym`: Contains the robotics arm environments.
# - `stable-baselines3`: The SB3 deep reinforcement learning library.
# - `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.
# - `huggingface_hub`: Library allowing anyone to work with the Hub repositories.
#
# ⏲ The installation can **take 10 minutes**.

# %%
# !pip install stable-baselines3[extra]
# !pip install gymnasium
# !pip install huggingface_sb3

# To fix the video rendering error, install compatible versions of Stable-Baselines3, Gymnasium, and huggingface_sb3.

# !pip install gymnasium==0.29.1
# !pip install panda_gym
# !pip install stable-baselines3==2.3.2

# !pip install huggingface_sb3==3.0
# !pip install huggingface_hub
# Out:
# Collecting gymnasium==0.29.1
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.29.1) (0.0.6)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 20.1 MB/s eta 0:00:00
# Installing collected packages: gymnasium
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.3.0
#     Uninstalling gymnasium-1.3.0:
#       Successfully uninstalled gymnasium-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Successfully installed gymnasium-0.29.1
# Collecting panda_gym
#   Downloading panda_gym-3.0.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: gymnasium>=0.26 in /usr/local/lib/python3.12/dist-packages (from panda_gym) (0.29.1)
# Collecting pybullet (from panda_gym)
#   Downloading pybullet-3.2.7.tar.gz (80.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 MB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from panda_gym) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from panda_gym) (1.16.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.26->panda_gym) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.26->panda_gym) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.26->panda_gym) (0.0.6)
# Downloading panda_gym-3.0.7-py3-none-any.whl (23 kB)
# Building wheels for collected packages: pybullet
#   Building wheel for pybullet (setup.py) ... done
#   Created wheel for pybullet: filename=pybullet-3.2.7-cp312-cp312-linux_x86_64.whl size=99873461 sha256=9222e12aedf86bb950d4b259d61d033a45df035caebe12897e71ed9df4f9e5bc
#   Stored in directory: /root/.cache/pip/wheels/72/95/1d/b336e5ee612ae9a019bfff4dc0bedd100ee6f0570db205fdf8
# Successfully built pybullet
# Installing collected packages: pybullet, panda_gym
# Successfully installed panda_gym-3.0.7 pybullet-3.2.7
# Collecting stable-baselines3==2.3.2
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.3.2) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.3.2) (2.0.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.3.2) (2.11.0+cu128)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.3.2) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.3.2) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.3.2) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3==2.3.2) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3==2.3.2) (0.0.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (3.29.4)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->stable-baselines3==2.3.2) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.13->stable-baselines3==2.3.2) (12.8.90)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.3.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.3.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.3.2) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.3.2) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.3.2) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.3.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.3.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.3.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.3.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.3.2) (2026.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.13->stable-baselines3==2.3.2) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.3.2) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13->stable-baselines3==2.3.2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13->stable-baselines3==2.3.2) (3.0.3)
# Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.3.2
# Collecting huggingface_sb3==3.0
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting huggingface-hub~=0.8 (from huggingface_sb3==3.0)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3==3.0) (6.0.3)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3==3.0) (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3==3.0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3==3.0) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3==3.0) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3==3.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3==3.0) (1.5.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3==3.0) (26.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3==3.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3==3.0) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3==3.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3==3.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3==3.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3==3.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3==3.0) (2026.6.17)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 14.6 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub, huggingface_sb3
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.20.1
#     Uninstalling huggingface_hub-1.20.1:
#       Successfully uninstalled huggingface_hub-1.20.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 6.19.0 requires huggingface-hub<2.0,>=1.2.0, but you have huggingface-hub 0.36.2 which is incompatible.
# transformers 5.12.1 requires huggingface-hub<2.0,>=1.5.0, but you have huggingface-hub 0.36.2 which is incompatible.
# Successfully installed huggingface-hub-0.36.2 huggingface_sb3-3.0
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.5.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2026.6.17)

# %%
# Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# save the package version
# !pip freeze > /content/drive/MyDrive/models/requirements_a2c_PandaReachDense_v3.txt

# !pip freeze | grep -E "stable-baselines3|panda-gym|gymnasium|torch" > requirements.txt

# %%
# To restore the package

# !pip install -r /content/drive/MyDrive/models/requirements_a2c_PandaReachDense_v3.txt

# %% [markdown]
# ## Import the packages 📦

# %%
import os

import gymnasium as gym
import panda_gym

from huggingface_sb3 import load_from_hub, package_to_hub

from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env

from huggingface_hub import notebook_login
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## PandaReachDense-v3 🦾
#
# The agent we're going to train is a robotic arm that needs to do controls (moving the arm and using the end-effector).
#
# In robotics, the *end-effector* is the device at the end of a robotic arm designed to interact with the environment.
#
# In `PandaReach`, the robot must place its end-effector at a target position (green ball).
#
# We're going to use the dense version of this environment. It means we'll get a *dense reward function* that **will provide a reward at each timestep** (the closer the agent is to completing the task, the higher the reward). Contrary to a *sparse reward function* where the environment **return a reward if and only if the task is completed**.
#
# Also, we're going to use the *End-effector displacement control*, it means the **action corresponds to the displacement of the end-effector**. We don't control the individual motion of each joint (joint control).
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/robotics.jpg"  alt="Robotics"/>
#
#
# This way **the training will be easier**.

# %% [markdown]
# ### Create the environment
#
# #### The environment 🎮
#
# In `PandaReachDense-v3` the robotic arm must place its end-effector at a target position (green ball).

# %%
env_id = "PandaReachDense-v3"

# Create the env
env = gym.make(env_id)

# Get the state space and action space
s_size = env.observation_space.shape
a_size = env.action_space

# %%
print("_____OBSERVATION SPACE_____ \n")
print("The State Space is: ", s_size)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# The State Space is:  None
# Sample observation OrderedDict({'achieved_goal': array([-2.981375 ,  9.658257 , -2.7046099], dtype=float32), 'desired_goal': array([8.696864, 5.334226, 9.826871], dtype=float32), 'observation': array([-9.901244 , -3.0178602, -5.1219163,  3.8371124, -0.9431574,
#         9.536911 ], dtype=float32)})

# %% [markdown]
# The observation space **is a dictionary with 3 different elements**:
# - `achieved_goal`: (x,y,z) the current position of the end-effector.
# - `desired_goal`: (x,y,z) the target position for the end-effector.
# - `observation`: position (x,y,z) and velocity of the end-effector (vx, vy, vz).
#
# Given it's a dictionary as observation, **we will need to use a MultiInputPolicy policy instead of MlpPolicy**.

# %%
print("\n _____ACTION SPACE_____ \n")
print("The Action Space is: ", a_size)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# The Action Space is:  Box(-1.0, 1.0, (3,), float32)
# Action Space Sample [ 0.08267706 -0.8052398  -0.78946626]

# %% [markdown]
# The action space is a vector with 3 values:
# - Control x, y, z movement

# %% [markdown]
# ### Normalize observation and rewards

# %% [markdown]
# A good practice in reinforcement learning is to [normalize input features](https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html).
#
# For that purpose, there is a wrapper that will compute a running average and standard deviation of input features.
#
# We also normalize rewards with this same wrapper by adding `norm_reward = True`
#
# [You should check the documentation to fill this cell](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecnormalize)

# %%
env = make_vec_env(env_id, n_envs=4)

# Adding this wrapper to normalize the observation and the reward
env = # TODO: Add the wrapper

# %% [markdown]
# #### Solution

# %%
env = make_vec_env(env_id, n_envs=4)

env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# %% [markdown]
# ### Create the A2C Model 🤖
#
# For more information about A2C implementation with StableBaselines3 check: https://stable-baselines3.readthedocs.io/en/master/modules/a2c.html#notes
#
# To find the best parameters I checked the [official trained agents by Stable-Baselines3 team](https://huggingface.co/sb3).

# %%
model = # Create the A2C model and try to find the best parameters

# %% [markdown]
# #### Solution

# %%
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1) # mean_reward on PandaReachDense-v3 --> -0.19 +/- 0.09


# model = A2C(
#     policy = "MultiInputPolicy",
#     env= env,
#     learning_rate=7e-4,
#     n_steps=8,
#     gamma=0.95,
#     gae_lambda=0.9,
#     ent_coef=0.0,
#     vf_coef=0.4,
#     max_grad_norm=0.5,
#     normalize_advantage=True,
#     use_sde=True,
#     sde_sample_freq=4,
#     policy_kwargs=dict(net_arch=[64, 64]),
#     tensorboard_log="./a2c_panda_tensorboard/",
#     verbose=1,
# ) # mean_reward on PandaReachDense-v3 --> -0.20 +/- 0.09
# Out:
# Using cuda device

# %% [markdown]
# ### Train the A2C agent 🏃
# - Let's train our agent for 1,000,000 timesteps, don't forget to use GPU on Colab. It will take approximately ~25-40min

# %%
model.learn(1_000_000)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    std                | 0.383     |
# |    value_loss         | 7.61e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.73      |
# |    ep_rew_mean        | -0.22     |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 374       |
# |    iterations         | 23800     |
# |    time_elapsed       | 1270      |
# |    total_timesteps    | 476000    |
# | train/                |           |
# |    entropy_loss       | -1.22     |
# |    explained_variance | 0.9788297 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 23799     |
# |    policy_loss        | -0.000117 |
# |    std                | 0.379     |
# |    value_loss         | 0.000123  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.68       |
# |    ep_rew_mean        | -0.202     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 374        |
# |    iterations         | 23900      |
# |    time_elapsed       | 1275       |
# |    total_timesteps    | 478000     |
# | train/                |            |
# |    entropy_loss       | -1.22      |
# |    explained_variance | 0.99176806 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 23899      |
# |    policy_loss        | 0.00428    |
# |    std                | 0.379      |
# |    value_loss         | 8.03e-05   |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76     |
# |    ep_rew_mean        | -0.222   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 24000    |
# |    time_elapsed       | 1280     |
# |    total_timesteps    | 480000   |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | 0.971738 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 23999    |
# |    policy_loss        | 0.00103  |
# |    std                | 0.374    |
# |    value_loss         | 0.00011  |
# ------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.77       |
# |    ep_rew_mean        | -0.214     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 374        |
# |    iterations         | 24100      |
# |    time_elapsed       | 1286       |
# |    total_timesteps    | 482000     |
# | train/                |            |
# |    entropy_loss       | -1.16      |
# |    explained_variance | 0.92530876 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 24099      |
# |    policy_loss        | 0.00695    |
# |    std                | 0.373      |
# |    value_loss         | 0.000314   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.64       |
# |    ep_rew_mean        | -0.202     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 374        |
# |    iterations         | 24200      |
# |    time_elapsed       | 1291       |
# |    total_timesteps    | 484000     |
# | train/                |            |
# |    entropy_loss       | -1.15      |
# |    explained_variance | 0.92200977 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 24199      |
# |    policy_loss        | -0.00687   |
# |    std                | 0.371      |
# |    value_loss         | 0.000179   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.69       |
# |    ep_rew_mean        | -0.208     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 374        |
# |    iterations         | 24300      |
# |    time_elapsed       | 1296       |
# |    total_timesteps    | 486000     |
# | train/                |            |
# |    entropy_loss       | -1.13      |
# |    explained_variance | 0.95812416 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 24299      |
# |    policy_loss        | -0.00374   |
# |    std                | 0.369      |
# |    value_loss         | 0.0003     |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.78      |
# |    ep_rew_mean        | -0.223    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 374       |
# |    iterations         | 24400     |
# |    time_elapsed       | 1302      |
# |    total_timesteps    | 488000    |
# | train/                |           |
# |    entropy_loss       | -1.11     |
# |    explained_variance | 0.7993423 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24399     |
# |    policy_loss        | -0.00251  |
# |    std                | 0.367     |
# |    value_loss         | 0.000921  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.74      |
# |    ep_rew_mean        | -0.215    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 374       |
# |    iterations         | 24500     |
# |    time_elapsed       | 1306      |
# |    total_timesteps    | 490000    |
# | train/                |           |
# |    entropy_loss       | -1.11     |
# |    explained_variance | 0.9605232 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24499     |
# |    policy_loss        | 0.0104    |
# |    std                | 0.366     |
# |    value_loss         | 0.00036   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.78      |
# |    ep_rew_mean        | -0.214    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 374       |
# |    iterations         | 24600     |
# |    time_elapsed       | 1312      |
# |    total_timesteps    | 492000    |
# | train/                |           |
# |    entropy_loss       | -1.1      |
# |    explained_variance | 0.9250012 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24599     |
# |    policy_loss        | 0.00834   |
# |    std                | 0.365     |
# |    value_loss         | 0.000524  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.8        |
# |    ep_rew_mean        | -0.219     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 374        |
# |    iterations         | 24700      |
# |    time_elapsed       | 1317       |
# |    total_timesteps    | 494000     |
# | train/                |            |
# |    entropy_loss       | -1.08      |
# |    explained_variance | 0.97378796 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 24699      |
# |    policy_loss        | -0.0057    |
# |    std                | 0.364      |
# |    value_loss         | 0.000256   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.7       |
# |    ep_rew_mean        | -0.205    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 24800     |
# |    time_elapsed       | 1322      |
# |    total_timesteps    | 496000    |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | 0.9158159 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 24799     |
# |    policy_loss        | -0.00658  |
# |    std                | 0.362     |
# |    value_loss         | 0.000299  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.73       |
# |    ep_rew_mean        | -0.203     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 374        |
# |    iterations         | 24900      |
# |    time_elapsed       | 1328       |
# |    total_timesteps    | 498000     |
# | train/                |            |
# |    entropy_loss       | -1.05      |
# |    explained_variance | 0.96171033 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 24899      |
# |    policy_loss        | 0.0054     |
# |    std                | 0.36       |
# |    value_loss         | 0.000152   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.72       |
# |    ep_rew_mean        | -0.219     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 374        |
# |    iterations         | 25000      |
# |    time_elapsed       | 1333       |
# |    total_timesteps    | 500000     |
# | train/                |            |
# |    entropy_loss       | -1.06      |
# |    explained_variance | 0.89283997 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 24999      |
# |    policy_loss        | -0.000693  |
# |    std                | 0.361      |
# |    value_loss         | 0.000506   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.73      |
# |    ep_rew_mean        | -0.223    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 25100     |
# |    time_elapsed       | 1338      |
# |    total_timesteps    | 502000    |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | 0.9873357 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25099     |
# |    policy_loss        | -0.00125  |
# |    std                | 0.363     |
# |    value_loss         | 7.29e-05  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.77       |
# |    ep_rew_mean        | -0.208     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 374        |
# |    iterations         | 25200      |
# |    time_elapsed       | 1344       |
# |    total_timesteps    | 504000     |
# | train/                |            |
# |    entropy_loss       | -1.05      |
# |    explained_variance | 0.72856665 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 25199      |
# |    policy_loss        | -0.00561   |
# |    std                | 0.361      |
# |    value_loss         | 0.000601   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.69       |
# |    ep_rew_mean        | -0.205     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 25300      |
# |    time_elapsed       | 1349       |
# |    total_timesteps    | 506000     |
# | train/                |            |
# |    entropy_loss       | -1.03      |
# |    explained_variance | 0.97019655 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 25299      |
# |    policy_loss        | -0.00012   |
# |    std                | 0.36       |
# |    value_loss         | 0.000132   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.76      |
# |    ep_rew_mean        | -0.206    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 25400     |
# |    time_elapsed       | 1353      |
# |    total_timesteps    | 508000    |
# | train/                |           |
# |    entropy_loss       | -1.03     |
# |    explained_variance | 0.9703116 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25399     |
# |    policy_loss        | -0.00701  |
# |    std                | 0.36      |
# |    value_loss         | 0.000203  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.62       |
# |    ep_rew_mean        | -0.2       |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 374        |
# |    iterations         | 25500      |
# |    time_elapsed       | 1360       |
# |    total_timesteps    | 510000     |
# | train/                |            |
# |    entropy_loss       | -1.02      |
# |    explained_variance | 0.94157827 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 25499      |
# |    policy_loss        | -0.00822   |
# |    std                | 0.357      |
# |    value_loss         | 0.000296   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.79      |
# |    ep_rew_mean        | -0.212    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 25600     |
# |    time_elapsed       | 1364      |
# |    total_timesteps    | 512000    |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | 0.9536134 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25599     |
# |    policy_loss        | -0.0104   |
# |    std                | 0.356     |
# |    value_loss         | 0.000198  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.86       |
# |    ep_rew_mean        | -0.237     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 25700      |
# |    time_elapsed       | 1369       |
# |    total_timesteps    | 514000     |
# | train/                |            |
# |    entropy_loss       | -0.984     |
# |    explained_variance | 0.96589994 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 25699      |
# |    policy_loss        | -0.0105    |
# |    std                | 0.354      |
# |    value_loss         | 0.000257   |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.74     |
# |    ep_rew_mean        | -0.21    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 25800    |
# |    time_elapsed       | 1375     |
# |    total_timesteps    | 516000   |
# | train/                |          |
# |    entropy_loss       | -0.973   |
# |    explained_variance | 0.981353 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 25799    |
# |    policy_loss        | -0.00797 |
# |    std                | 0.354    |
# |    value_loss         | 9.28e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.63      |
# |    ep_rew_mean        | -0.204    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 25900     |
# |    time_elapsed       | 1380      |
# |    total_timesteps    | 518000    |
# | train/                |           |
# |    entropy_loss       | -0.934    |
# |    explained_variance | 0.9666039 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 25899     |
# |    policy_loss        | -0.00238  |
# |    std                | 0.349     |
# |    value_loss         | 0.000237  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.69       |
# |    ep_rew_mean        | -0.208     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 26000      |
# |    time_elapsed       | 1385       |
# |    total_timesteps    | 520000     |
# | train/                |            |
# |    entropy_loss       | -0.939     |
# |    explained_variance | 0.98836243 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 25999      |
# |    policy_loss        | 0.00856    |
# |    std                | 0.35       |
# |    value_loss         | 0.000135   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.65      |
# |    ep_rew_mean        | -0.194    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 26100     |
# |    time_elapsed       | 1391      |
# |    total_timesteps    | 522000    |
# | train/                |           |
# |    entropy_loss       | -0.914    |
# |    explained_variance | 0.9690268 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26099     |
# |    policy_loss        | 0.0023    |
# |    std                | 0.347     |
# |    value_loss         | 0.000121  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.86      |
# |    ep_rew_mean        | -0.232    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 26200     |
# |    time_elapsed       | 1395      |
# |    total_timesteps    | 524000    |
# | train/                |           |
# |    entropy_loss       | -0.886    |
# |    explained_variance | 0.9672263 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26199     |
# |    policy_loss        | 0.00612   |
# |    std                | 0.345     |
# |    value_loss         | 0.000235  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.71       |
# |    ep_rew_mean        | -0.213     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 26300      |
# |    time_elapsed       | 1401       |
# |    total_timesteps    | 526000     |
# | train/                |            |
# |    entropy_loss       | -0.864     |
# |    explained_variance | 0.90565306 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 26299      |
# |    policy_loss        | -0.014     |
# |    std                | 0.343      |
# |    value_loss         | 0.000554   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.19      |
# |    ep_rew_mean        | -0.25     |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 26400     |
# |    time_elapsed       | 1406      |
# |    total_timesteps    | 528000    |
# | train/                |           |
# |    entropy_loss       | -0.845    |
# |    explained_variance | 0.9170354 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26399     |
# |    policy_loss        | -0.015    |
# |    std                | 0.342     |
# |    value_loss         | 0.000689  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.12      |
# |    ep_rew_mean        | -0.254    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 26500     |
# |    time_elapsed       | 1410      |
# |    total_timesteps    | 530000    |
# | train/                |           |
# |    entropy_loss       | -0.845    |
# |    explained_variance | 0.8712791 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 26499     |
# |    policy_loss        | -0.0102   |
# |    std                | 0.342     |
# |    value_loss         | 0.00145   |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.96       |
# |    ep_rew_mean        | -0.228     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 26600      |
# |    time_elapsed       | 1416       |
# |    total_timesteps    | 532000     |
# | train/                |            |
# |    entropy_loss       | -0.835     |
# |    explained_variance | 0.82517916 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 26599      |
# |    policy_loss        | -0.0367    |
# |    std                | 0.341      |
# |    value_loss         | 0.00173    |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.82       |
# |    ep_rew_mean        | -0.22      |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 26700      |
# |    time_elapsed       | 1421       |
# |    total_timesteps    | 534000     |
# | train/                |            |
# |    entropy_loss       | -0.837     |
# |    explained_variance | 0.87432635 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 26699      |
# |    policy_loss        | -0.0211    |
# |    std                | 0.341      |
# |    value_loss         | 0.000587   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.84       |
# |    ep_rew_mean        | -0.217     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 26800      |
# |    time_elapsed       | 1425       |
# |    total_timesteps    | 536000     |
# | train/                |            |
# |    entropy_loss       | -0.811     |
# |    explained_variance | 0.90327984 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 26799      |
# |    policy_loss        | 0.0154     |
# |    std                | 0.338      |
# |    value_loss         | 0.00155    |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 3.35        |
# |    ep_rew_mean        | -0.261      |
# |    success_rate       | 0.99        |
# | time/                 |             |
# |    fps                | 375         |
# |    iterations         | 26900       |
# |    time_elapsed       | 1432        |
# |    total_timesteps    | 538000      |
# | train/                |             |
# |    entropy_loss       | -0.801      |
# |    explained_variance | 0.103105664 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 26899       |
# |    policy_loss        | -0.0582     |
# |    std                | 0.337       |
# |    value_loss         | 0.008       |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 3.12       |
# |    ep_rew_mean        | -0.254     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 27000      |
# |    time_elapsed       | 1436       |
# |    total_timesteps    | 540000     |
# | train/                |            |
# |    entropy_loss       | -0.774     |
# |    explained_variance | 0.90484285 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 26999      |
# |    policy_loss        | 0.0215     |
# |    std                | 0.334      |
# |    value_loss         | 0.0212     |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 3.08       |
# |    ep_rew_mean        | -0.237     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 27100      |
# |    time_elapsed       | 1441       |
# |    total_timesteps    | 542000     |
# | train/                |            |
# |    entropy_loss       | -0.732     |
# |    explained_variance | 0.94360715 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 27099      |
# |    policy_loss        | -0.0342    |
# |    std                | 0.328      |
# |    value_loss         | 0.0194     |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.84      |
# |    ep_rew_mean        | -0.213    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 375       |
# |    iterations         | 27200     |
# |    time_elapsed       | 1447      |
# |    total_timesteps    | 544000    |
# | train/                |           |
# |    entropy_loss       | -0.708    |
# |    explained_variance | 0.8579436 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27199     |
# |    policy_loss        | 0.00338   |
# |    std                | 0.326     |
# |    value_loss         | 0.000482  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.208   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 27300    |
# |    time_elapsed       | 1452     |
# |    total_timesteps    | 546000   |
# | train/                |          |
# |    entropy_loss       | -0.699   |
# |    explained_variance | 0.928872 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 27299    |
# |    policy_loss        | -0.00413 |
# |    std                | 0.325    |
# |    value_loss         | 0.000299 |
# ------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.65       |
# |    ep_rew_mean        | -0.203     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 27400      |
# |    time_elapsed       | 1456       |
# |    total_timesteps    | 548000     |
# | train/                |            |
# |    entropy_loss       | -0.691     |
# |    explained_variance | 0.88700575 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 27399      |
# |    policy_loss        | -0.00531   |
# |    std                | 0.324      |
# |    value_loss         | 0.000692   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.8        |
# |    ep_rew_mean        | -0.227     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 375        |
# |    iterations         | 27500      |
# |    time_elapsed       | 1462       |
# |    total_timesteps    | 550000     |
# | train/                |            |
# |    entropy_loss       | -0.69      |
# |    explained_variance | 0.97444016 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 27499      |
# |    policy_loss        | -0.0192    |
# |    std                | 0.324      |
# |    value_loss         | 0.000456   |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.206   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 27600    |
# |    time_elapsed       | 1467     |
# |    total_timesteps    | 552000   |
# | train/                |          |
# |    entropy_loss       | -0.684   |
# |    explained_variance | 0.93892  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 27599    |
# |    policy_loss        | 0.00413  |
# |    std                | 0.324    |
# |    value_loss         | 0.000458 |
# ------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.87       |
# |    ep_rew_mean        | -0.233     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 27700      |
# |    time_elapsed       | 1472       |
# |    total_timesteps    | 554000     |
# | train/                |            |
# |    entropy_loss       | -0.672     |
# |    explained_variance | 0.82805264 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 27699      |
# |    policy_loss        | 0.00691    |
# |    std                | 0.323      |
# |    value_loss         | 0.00105    |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.72       |
# |    ep_rew_mean        | -0.204     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 27800      |
# |    time_elapsed       | 1478       |
# |    total_timesteps    | 556000     |
# | train/                |            |
# |    entropy_loss       | -0.66      |
# |    explained_variance | 0.98257977 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 27799      |
# |    policy_loss        | -0.00705   |
# |    std                | 0.321      |
# |    value_loss         | 8.84e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.68      |
# |    ep_rew_mean        | -0.211    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 27900     |
# |    time_elapsed       | 1482      |
# |    total_timesteps    | 558000    |
# | train/                |           |
# |    entropy_loss       | -0.647    |
# |    explained_variance | 0.9752698 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27899     |
# |    policy_loss        | -0.00395  |
# |    std                | 0.32      |
# |    value_loss         | 0.000215  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.72      |
# |    ep_rew_mean        | -0.213    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 28000     |
# |    time_elapsed       | 1488      |
# |    total_timesteps    | 560000    |
# | train/                |           |
# |    entropy_loss       | -0.64     |
# |    explained_variance | 0.9737441 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 27999     |
# |    policy_loss        | -0.00263  |
# |    std                | 0.32      |
# |    value_loss         | 0.000124  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.61      |
# |    ep_rew_mean        | -0.198    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 28100     |
# |    time_elapsed       | 1493      |
# |    total_timesteps    | 562000    |
# | train/                |           |
# |    entropy_loss       | -0.613    |
# |    explained_variance | 0.9642152 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 28099     |
# |    policy_loss        | -0.00248  |
# |    std                | 0.318     |
# |    value_loss         | 0.000184  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.77      |
# |    ep_rew_mean        | -0.214    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 28200     |
# |    time_elapsed       | 1498      |
# |    total_timesteps    | 564000    |
# | train/                |           |
# |    entropy_loss       | -0.615    |
# |    explained_variance | 0.9872674 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 28199     |
# |    policy_loss        | 0.00341   |
# |    std                | 0.319     |
# |    value_loss         | 7.18e-05  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.64       |
# |    ep_rew_mean        | -0.205     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 28300      |
# |    time_elapsed       | 1503       |
# |    total_timesteps    | 566000     |
# | train/                |            |
# |    entropy_loss       | -0.603     |
# |    explained_variance | 0.98854893 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 28299      |
# |    policy_loss        | -0.00255   |
# |    std                | 0.319      |
# |    value_loss         | 7.91e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.61      |
# |    ep_rew_mean        | -0.202    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 28400     |
# |    time_elapsed       | 1508      |
# |    total_timesteps    | 568000    |
# | train/                |           |
# |    entropy_loss       | -0.586    |
# |    explained_variance | 0.9745079 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 28399     |
# |    policy_loss        | -0.0139   |
# |    std                | 0.317     |
# |    value_loss         | 0.000229  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.208   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 28500    |
# |    time_elapsed       | 1513     |
# |    total_timesteps    | 570000   |
# | train/                |          |
# |    entropy_loss       | -0.59    |
# |    explained_variance | 0.936308 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 28499    |
# |    policy_loss        | 0.0182   |
# |    std                | 0.319    |
# |    value_loss         | 0.000809 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.58      |
# |    ep_rew_mean        | -0.201    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 28600     |
# |    time_elapsed       | 1519      |
# |    total_timesteps    | 572000    |
# | train/                |           |
# |    entropy_loss       | -0.588    |
# |    explained_variance | 0.9883108 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 28599     |
# |    policy_loss        | 0.00445   |
# |    std                | 0.318     |
# |    value_loss         | 0.000226  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.89       |
# |    ep_rew_mean        | -0.235     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 28700      |
# |    time_elapsed       | 1524       |
# |    total_timesteps    | 574000     |
# | train/                |            |
# |    entropy_loss       | -0.58      |
# |    explained_variance | 0.95087343 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 28699      |
# |    policy_loss        | 0.00152    |
# |    std                | 0.317      |
# |    value_loss         | 0.000224   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.63       |
# |    ep_rew_mean        | -0.203     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 28800      |
# |    time_elapsed       | 1528       |
# |    total_timesteps    | 576000     |
# | train/                |            |
# |    entropy_loss       | -0.577     |
# |    explained_variance | 0.97735137 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 28799      |
# |    policy_loss        | 0.0022     |
# |    std                | 0.317      |
# |    value_loss         | 0.000307   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.69       |
# |    ep_rew_mean        | -0.206     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 28900      |
# |    time_elapsed       | 1534       |
# |    total_timesteps    | 578000     |
# | train/                |            |
# |    entropy_loss       | -0.553     |
# |    explained_variance | 0.96738255 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 28899      |
# |    policy_loss        | -0.00847   |
# |    std                | 0.315      |
# |    value_loss         | 0.000165   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.86      |
# |    ep_rew_mean        | -0.234    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 29000     |
# |    time_elapsed       | 1539      |
# |    total_timesteps    | 580000    |
# | train/                |           |
# |    entropy_loss       | -0.527    |
# |    explained_variance | 0.9311105 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 28999     |
# |    policy_loss        | -0.0106   |
# |    std                | 0.312     |
# |    value_loss         | 0.000376  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.63      |
# |    ep_rew_mean        | -0.205    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 29100     |
# |    time_elapsed       | 1543      |
# |    total_timesteps    | 582000    |
# | train/                |           |
# |    entropy_loss       | -0.529    |
# |    explained_variance | 0.9887429 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29099     |
# |    policy_loss        | 0.00105   |
# |    std                | 0.312     |
# |    value_loss         | 4.3e-05   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.76      |
# |    ep_rew_mean        | -0.223    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 29200     |
# |    time_elapsed       | 1550      |
# |    total_timesteps    | 584000    |
# | train/                |           |
# |    entropy_loss       | -0.509    |
# |    explained_variance | 0.9867752 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29199     |
# |    policy_loss        | 0.00318   |
# |    std                | 0.31      |
# |    value_loss         | 7.06e-05  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.73       |
# |    ep_rew_mean        | -0.205     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 29300      |
# |    time_elapsed       | 1554       |
# |    total_timesteps    | 586000     |
# | train/                |            |
# |    entropy_loss       | -0.478     |
# |    explained_variance | 0.91109794 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 29299      |
# |    policy_loss        | -0.00542   |
# |    std                | 0.307      |
# |    value_loss         | 0.000282   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.67      |
# |    ep_rew_mean        | -0.203    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 29400     |
# |    time_elapsed       | 1559      |
# |    total_timesteps    | 588000    |
# | train/                |           |
# |    entropy_loss       | -0.471    |
# |    explained_variance | 0.9867613 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29399     |
# |    policy_loss        | -0.00704  |
# |    std                | 0.306     |
# |    value_loss         | 0.00017   |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.7        |
# |    ep_rew_mean        | -0.218     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 29500      |
# |    time_elapsed       | 1565       |
# |    total_timesteps    | 590000     |
# | train/                |            |
# |    entropy_loss       | -0.447     |
# |    explained_variance | 0.97537476 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 29499      |
# |    policy_loss        | 0.000297   |
# |    std                | 0.304      |
# |    value_loss         | 0.000112   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.72      |
# |    ep_rew_mean        | -0.206    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 29600     |
# |    time_elapsed       | 1570      |
# |    total_timesteps    | 592000    |
# | train/                |           |
# |    entropy_loss       | -0.434    |
# |    explained_variance | 0.9361835 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29599     |
# |    policy_loss        | 0.0169    |
# |    std                | 0.303     |
# |    value_loss         | 0.000632  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.76       |
# |    ep_rew_mean        | -0.208     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 376        |
# |    iterations         | 29700      |
# |    time_elapsed       | 1575       |
# |    total_timesteps    | 594000     |
# | train/                |            |
# |    entropy_loss       | -0.416     |
# |    explained_variance | 0.94073176 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 29699      |
# |    policy_loss        | 0.0076     |
# |    std                | 0.301      |
# |    value_loss         | 0.0008     |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.8       |
# |    ep_rew_mean        | -0.223    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 29800     |
# |    time_elapsed       | 1581      |
# |    total_timesteps    | 596000    |
# | train/                |           |
# |    entropy_loss       | -0.426    |
# |    explained_variance | 0.9920664 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29799     |
# |    policy_loss        | -0.000412 |
# |    std                | 0.302     |
# |    value_loss         | 6.25e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.63      |
# |    ep_rew_mean        | -0.21     |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 377       |
# |    iterations         | 29900     |
# |    time_elapsed       | 1586      |
# |    total_timesteps    | 598000    |
# | train/                |           |
# |    entropy_loss       | -0.412    |
# |    explained_variance | 0.9793639 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29899     |
# |    policy_loss        | -0.00688  |
# |    std                | 0.3       |
# |    value_loss         | 0.000209  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.75      |
# |    ep_rew_mean        | -0.213    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 376       |
# |    iterations         | 30000     |
# |    time_elapsed       | 1591      |
# |    total_timesteps    | 600000    |
# | train/                |           |
# |    entropy_loss       | -0.404    |
# |    explained_variance | 0.9805872 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29999     |
# |    policy_loss        | -0.00816  |
# |    std                | 0.3       |
# |    value_loss         | 0.000169  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.67       |
# |    ep_rew_mean        | -0.214     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 377        |
# |    iterations         | 30100      |
# |    time_elapsed       | 1596       |
# |    total_timesteps    | 602000     |
# | train/                |            |
# |    entropy_loss       | -0.399     |
# |    explained_variance | 0.98830235 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 30099      |
# |    policy_loss        | -5.72e-05  |
# |    std                | 0.3        |
# |    value_loss         | 3.89e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.71      |
# |    ep_rew_mean        | -0.211    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 377       |
# |    iterations         | 30200     |
# |    time_elapsed       | 1601      |
# |    total_timesteps    | 604000    |
# | train/                |           |
# |    entropy_loss       | -0.365    |
# |    explained_variance | 0.9900477 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 30199     |
# |    policy_loss        | -0.0033   |
# |    std                | 0.296     |
# |    value_loss         | 0.000107  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.77       |
# |    ep_rew_mean        | -0.22      |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 377        |
# |    iterations         | 30300      |
# |    time_elapsed       | 1607       |
# |    total_timesteps    | 606000     |
# ...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.67      |
# |    ep_rew_mean        | -0.199    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 380       |
# |    iterations         | 47900     |
# |    time_elapsed       | 2516      |
# |    total_timesteps    | 958000    |
# | train/                |           |
# |    entropy_loss       | 0.952     |
# |    explained_variance | 0.9954679 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47899     |
# |    policy_loss        | -0.0075   |
# |    std                | 0.202     |
# |    value_loss         | 9.97e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.58      |
# |    ep_rew_mean        | -0.196    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 380       |
# |    iterations         | 48000     |
# |    time_elapsed       | 2521      |
# |    total_timesteps    | 960000    |
# | train/                |           |
# |    entropy_loss       | 0.945     |
# |    explained_variance | 0.9475437 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 47999     |
# |    policy_loss        | -0.00368  |
# |    std                | 0.203     |
# |    value_loss         | 0.000389  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.68      |
# |    ep_rew_mean        | -0.214    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 380       |
# |    iterations         | 48100     |
# |    time_elapsed       | 2526      |
# |    total_timesteps    | 962000    |
# | train/                |           |
# |    entropy_loss       | 0.946     |
# |    explained_variance | 0.9194356 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48099     |
# |    policy_loss        | -0.00016  |
# |    std                | 0.203     |
# |    value_loss         | 0.000629  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.67       |
# |    ep_rew_mean        | -0.205     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 380        |
# |    iterations         | 48200      |
# |    time_elapsed       | 2531       |
# |    total_timesteps    | 964000     |
# | train/                |            |
# |    entropy_loss       | 0.971      |
# |    explained_variance | 0.98526734 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 48199      |
# |    policy_loss        | 0.00555    |
# |    std                | 0.202      |
# |    value_loss         | 0.000105   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.68      |
# |    ep_rew_mean        | -0.21     |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 380       |
# |    iterations         | 48300     |
# |    time_elapsed       | 2536      |
# |    total_timesteps    | 966000    |
# | train/                |           |
# |    entropy_loss       | 0.975     |
# |    explained_variance | 0.9781788 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48299     |
# |    policy_loss        | -0.00117  |
# |    std                | 0.202     |
# |    value_loss         | 0.000173  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.74       |
# |    ep_rew_mean        | -0.214     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 380        |
# |    iterations         | 48400      |
# |    time_elapsed       | 2542       |
# |    total_timesteps    | 968000     |
# | train/                |            |
# |    entropy_loss       | 0.995      |
# |    explained_variance | 0.99014026 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 48399      |
# |    policy_loss        | 0.003      |
# |    std                | 0.2        |
# |    value_loss         | 8.05e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.89       |
# |    ep_rew_mean        | -0.233     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 380        |
# |    iterations         | 48500      |
# |    time_elapsed       | 2547       |
# |    total_timesteps    | 970000     |
# | train/                |            |
# |    entropy_loss       | 1          |
# |    explained_variance | 0.97510344 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 48499      |
# |    policy_loss        | 0.00404    |
# |    std                | 0.2        |
# |    value_loss         | 0.000152   |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.65     |
# |    ep_rew_mean        | -0.208   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 48600    |
# |    time_elapsed       | 2551     |
# |    total_timesteps    | 972000   |
# | train/                |          |
# |    entropy_loss       | 1.03     |
# |    explained_variance | 0.983422 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48599    |
# |    policy_loss        | 0.00244  |
# |    std                | 0.198    |
# |    value_loss         | 0.000173 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.69      |
# |    ep_rew_mean        | -0.209    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 380       |
# |    iterations         | 48700     |
# |    time_elapsed       | 2557      |
# |    total_timesteps    | 974000    |
# | train/                |           |
# |    entropy_loss       | 1.02      |
# |    explained_variance | 0.9924254 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48699     |
# |    policy_loss        | 0.00107   |
# |    std                | 0.198     |
# |    value_loss         | 6.48e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.7       |
# |    ep_rew_mean        | -0.211    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 380       |
# |    iterations         | 48800     |
# |    time_elapsed       | 2562      |
# |    total_timesteps    | 976000    |
# | train/                |           |
# |    entropy_loss       | 1.02      |
# |    explained_variance | 0.9678469 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 48799     |
# |    policy_loss        | 9.1e-05   |
# |    std                | 0.198     |
# |    value_loss         | 0.000407  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.69       |
# |    ep_rew_mean        | -0.208     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 380        |
# |    iterations         | 48900      |
# |    time_elapsed       | 2567       |
# |    total_timesteps    | 978000     |
# | train/                |            |
# |    entropy_loss       | 1.04       |
# |    explained_variance | 0.97375506 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 48899      |
# |    policy_loss        | 0.00564    |
# |    std                | 0.198      |
# |    value_loss         | 0.000294   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.68       |
# |    ep_rew_mean        | -0.203     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 380        |
# |    iterations         | 49000      |
# |    time_elapsed       | 2573       |
# |    total_timesteps    | 980000     |
# | train/                |            |
# |    entropy_loss       | 1.02       |
# |    explained_variance | 0.98563015 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 48999      |
# |    policy_loss        | -0.011     |
# |    std                | 0.198      |
# |    value_loss         | 0.000169   |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.61     |
# |    ep_rew_mean        | -0.203   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 49100    |
# |    time_elapsed       | 2577     |
# |    total_timesteps    | 982000   |
# | train/                |          |
# |    entropy_loss       | 1.05     |
# |    explained_variance | 0.978895 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49099    |
# |    policy_loss        | -0.00856 |
# |    std                | 0.197    |
# |    value_loss         | 0.000174 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.75      |
# |    ep_rew_mean        | -0.219    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 381       |
# |    iterations         | 49200     |
# |    time_elapsed       | 2582      |
# |    total_timesteps    | 984000    |
# | train/                |           |
# |    entropy_loss       | 1.07      |
# |    explained_variance | 0.9760227 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49199     |
# |    policy_loss        | 0.00676   |
# |    std                | 0.195     |
# |    value_loss         | 0.0002    |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.78       |
# |    ep_rew_mean        | -0.217     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 380        |
# |    iterations         | 49300      |
# |    time_elapsed       | 2588       |
# |    total_timesteps    | 986000     |
# | train/                |            |
# |    entropy_loss       | 1.08       |
# |    explained_variance | 0.97431993 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 49299      |
# |    policy_loss        | -0.00563   |
# |    std                | 0.194      |
# |    value_loss         | 0.000303   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.64      |
# |    ep_rew_mean        | -0.203    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 381       |
# |    iterations         | 49400     |
# |    time_elapsed       | 2592      |
# |    total_timesteps    | 988000    |
# | train/                |           |
# |    entropy_loss       | 1.08      |
# |    explained_variance | 0.9813089 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49399     |
# |    policy_loss        | -0.00836  |
# |    std                | 0.195     |
# |    value_loss         | 0.000103  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.53      |
# |    ep_rew_mean        | -0.192    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 381       |
# |    iterations         | 49500     |
# |    time_elapsed       | 2597      |
# |    total_timesteps    | 990000    |
# | train/                |           |
# |    entropy_loss       | 1.07      |
# |    explained_variance | 0.9963523 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49499     |
# |    policy_loss        | -0.00349  |
# |    std                | 0.196     |
# |    value_loss         | 6.9e-05   |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.78       |
# |    ep_rew_mean        | -0.219     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 380        |
# |    iterations         | 49600      |
# |    time_elapsed       | 2603       |
# |    total_timesteps    | 992000     |
# | train/                |            |
# |    entropy_loss       | 1.09       |
# |    explained_variance | 0.92812824 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 49599      |
# |    policy_loss        | 0.0277     |
# |    std                | 0.195      |
# |    value_loss         | 0.00102    |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.7       |
# |    ep_rew_mean        | -0.21     |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 381       |
# |    iterations         | 49700     |
# |    time_elapsed       | 2608      |
# |    total_timesteps    | 994000    |
# | train/                |           |
# |    entropy_loss       | 1.09      |
# |    explained_variance | 0.9723771 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49699     |
# |    policy_loss        | 0.000741  |
# |    std                | 0.194     |
# |    value_loss         | 0.000267  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.75      |
# |    ep_rew_mean        | -0.209    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 381       |
# |    iterations         | 49800     |
# |    time_elapsed       | 2613      |
# |    total_timesteps    | 996000    |
# | train/                |           |
# |    entropy_loss       | 1.09      |
# |    explained_variance | 0.9280335 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49799     |
# |    policy_loss        | 0.0171    |
# |    std                | 0.195     |
# |    value_loss         | 0.000766  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 2.7        |
# |    ep_rew_mean        | -0.203     |
# |    success_rate       | 1          |
# | time/                 |            |
# |    fps                | 381        |
# |    iterations         | 49900      |
# |    time_elapsed       | 2618       |
# |    total_timesteps    | 998000     |
# | train/                |            |
# |    entropy_loss       | 1.08       |
# |    explained_variance | 0.95155853 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 49899      |
# |    policy_loss        | 0.0108     |
# |    std                | 0.196      |
# |    value_loss         | 0.000454   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.85      |
# |    ep_rew_mean        | -0.224    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 381       |
# |    iterations         | 50000     |
# |    time_elapsed       | 2623      |
# |    total_timesteps    | 1000000   |
# | train/                |           |
# |    entropy_loss       | 1.07      |
# |    explained_variance | 0.9639238 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 49999     |
# |    policy_loss        | 0.00121   |
# |    std                | 0.195     |
# |    value_loss         | 0.000385  |
# -------------------------------------

# %%
#Learning curve (open tensor board in a separate browser)

import subprocess
subprocess.Popen(["tensorboard", "--logdir", "./a2c_panda_tensorboard/", "--host", "0.0.0.0", "--port", "6006"])

# from google.colab import output
# output.serve_kernel_port_as_window(6006)

# Get just the URL instead of auto-opening
from google.colab.output import eval_js
url = eval_js("google.colab.kernel.proxyPort(6006)")
print(url)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# https://6006-gpu-t4-s-kkb-usw4a1-2mkmpo3lj99kf-a.us-west4-1.prod.colab.dev

# %%
# Save the model and  VecNormalize statistics when saving the agent
model.save("a2c-PandaReachDense-v3-1")
env.save("vec_normalize_a2c_PandaReachDense_v3-1.pkl")

# %%
# Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Save the model to Drive

model.save("/content/drive/MyDrive/models/3)_a2c-PandaReachDense-v3")
env.save("/content/drive/MyDrive/models/3)_vec_normalize_a2c_PandaReachDense_v3.pkl")

# %% [markdown]
# ### Evaluate the agent 📈
# - Now that's our  agent is trained, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`

# %%
import panda_gym
print(panda_gym.__version__)
# Out:
# 3.0.7

# %%
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaReachDense-v3")])
eval_env = VecNormalize.load("vec_normalize_a2c_PandaReachDense_v3-1.pkl", eval_env)
# eval_env = VecNormalize.load("/content/drive/MyDrive/models/3)_vec_normalize_a2c_PandaReachDense_v3.pkl", eval_env)

# We need to override the render_mode
eval_env.render_mode = "rgb_array"

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
# model = A2C.load("a2c-PandaReachDense-v3-1")
# model = A2C.load("/content/drive/MyDrive/models/a2c-PandaReachDense-v3-1")

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward = -0.20 +/- 0.11

# %%
print(eval_env.observation_space)
print(model.observation_space)
# Out:
# Dict('achieved_goal': Box(-10.0, 10.0, (3,), float32), 'desired_goal': Box(-10.0, 10.0, (3,), float32), 'observation': Box(-10.0, 10.0, (6,), float32))
# Dict('achieved_goal': Box(-10.0, 10.0, (3,), float32), 'desired_goal': Box(-10.0, 10.0, (3,), float32), 'observation': Box(-10.0, 10.0, (6,), float32))

# %%
# Create a separate environment for recording (by me)
from gymnasium.wrappers import RecordVideo
def make_env():
    return RecordVideo(
        gym.make(
            "PandaReachDense-v3",
            render_mode="rgb_array"
        ),
        video_folder="videos",
        episode_trigger=lambda episode: True,
    )

eval_env = DummyVecEnv([make_env])
eval_env = VecNormalize.load("vec_normalize_a2c_PandaReachDense_v3.pkl", eval_env)

eval_env.training = False
eval_env.norm_reward = False

# Load the model
model = A2C.load("a2c-PandaReachDense-v3")

# Run one episode manually
obs = eval_env.reset()

done = False
episode_reward = 0

while not done:
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = eval_env.step(action)
    episode_reward += reward[0]
eval_env.close()
print("Episode reward:", episode_reward)
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /content/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video /content/videos/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/videos/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/videos/rl-video-episode-0.mp4
# Moviepy - Building video /content/videos/rl-video-episode-1.mp4.
# Moviepy - Writing video /content/videos/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /content/videos/rl-video-episode-1.mp4
# Episode reward: -0.24765089

# %%
from IPython.display import Video

Video("videos/rl-video-episode-0.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ### Publish your trained model on the Hub 🔥
# Now that we saw we got good results after the training, we can publish our trained model on the Hub with one line of code.
#
# 📚 The libraries documentation 👉 https://github.com/huggingface/huggingface_sb3/tree/main#hugging-face--x-stable-baselines3-v20

# %% [markdown]
# By using `package_to_hub`, as we already mentionned in the former units, **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥 using `package_to_hub()` function

# %% [markdown]
# For this environment, **running this cell can take approximately 10min**

# %%
# # To fix the video rendering error, reinstall compatible versions of Stable-Baselines3, Gymnasium, and huggingface_sb3.

# !pip install stable-baselines3==2.3.2
# !pip install gymnasium==0.29.1
# !pip install huggingface_sb3==3.0

# %%
from huggingface_sb3 import package_to_hub

package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"Htar/a2c-{env_id}-no-hyperparameters", # Change the username
    commit_message="Initial commit",
)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /tmp/tmpa1tqc5cv/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpa1tqc5cv/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpa1tqc5cv/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpa1tqc5cv/-step-0-to-step-1000.mp4
# ℹ Pushing repo Htar/a2c-PandaReachDense-v3-no-hyperparameters to the
# Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:114: DeprecationWarning: hf_xet.upload_files() is deprecated. Use XetSession().new_upload_commit().start_upload_file() instead.
#   return fn(*args, **kwargs)
#   ...-v3/pytorch_variables.pth: 100%|##########| 1.26kB / 1.26kB
#   ...aReachDense-v3/policy.pth:  67%|######7   | 31.4kB / 46.8kB
#   ...2c-PandaReachDense-v3.zip:  67%|######7   | 77.2kB /  115kB
#   ...e-v3/policy.optimizer.pth:  67%|######7   | 32.7kB / 48.8kB
#   /tmp/tmpn0z9ytlg/replay.mp4 :  67%|######7   |  405kB /  604kB
#   ...0z9ytlg/vec_normalize.pkl:  67%|######7   | 1.77kB / 2.65kB
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Htar/a2c-PandaReachDense-v3-no-hyperparameters/tree/main/
# CommitInfo(commit_url='https://huggingface.co/Htar/a2c-PandaReachDense-v3-no-hyperparameters/commit/adf528f79a6dfd5ad5bc31ff9a7d40ed4f7d8b84', commit_message='Initial commit', commit_description='', oid='adf528f79a6dfd5ad5bc31ff9a7d40ed4f7d8b84', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Htar/a2c-PandaReachDense-v3-no-hyperparameters', endpoint='https://huggingface.co', repo_type='model', repo_id='Htar/a2c-PandaReachDense-v3-no-hyperparameters'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! Why not trying  `PandaPickAndPlace-v3`?
#
# If you want to try more advanced tasks for panda-gym, you need to check what was done using **TQC or SAC** (a more sample-efficient algorithm suited for robotics tasks). In real robotics, you'll use a more sample-efficient algorithm for a simple reason: contrary to a simulation **if you move your robotic arm too much, you have a risk of breaking it**.
#
# PandaPickAndPlace-v1 (this model uses the v1 version of the environment): https://huggingface.co/sb3/tqc-PandaPickAndPlace-v1
#
# And don't hesitate to check panda-gym documentation here: https://panda-gym.readthedocs.io/en/latest/usage/train_with_sb3.html
#
# We provide you the steps to train another agent (optional):
#
# 1. Define the environment called "PandaPickAndPlace-v3"
# 2. Make a vectorized environment
# 3. Add a wrapper to normalize the observations and rewards. [Check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecnormalize)
# 4. Create the A2C Model (don't forget verbose=1 to print the training logs).
# 5. Train it for 1M Timesteps
# 6. Save the model and  VecNormalize statistics when saving the agent
# 7. Evaluate your agent
# 8. Publish your trained model on the Hub 🔥 with `package_to_hub`

# %% [markdown]
# ### Solution (optional)

# %%
# 1 - 2
env_id = "PandaPickAndPlace-v3"
env = make_vec_env(env_id, n_envs=4)

# 3
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# 4
# model = A2C(policy = "MultiInputPolicy",
#             env = env,
#             verbose=1) mean_reward -45.00 +/- 15.00

model = A2C(
    policy = "MultiInputPolicy",
    env= env,
    learning_rate=7e-4,
    n_steps=8,
    gamma=0.95,
    gae_lambda=0.9,
    ent_coef=0.0,
    vf_coef=0.4,
    max_grad_norm=0.5,
    normalize_advantage=True,
    use_sde=True,
    sde_sample_freq=4,
    policy_kwargs=dict(net_arch=[64, 64]),
    tensorboard_log="./a2c_panda_tensorboard/",
    verbose=1,
)

# 5
model.learn(1_000_000)
# Out:
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Streaming output truncated to the last 5000 lines.
# |    std                | 1          |
# |    value_loss         | 0.00593    |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 47.5       |
# |    ep_rew_mean        | -47.5      |
# |    success_rate       | 0.05       |
# | time/                 |            |
# |    fps                | 317        |
# |    iterations         | 5000       |
# |    time_elapsed       | 503        |
# |    total_timesteps    | 160000     |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0.92633164 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -0.121     |
# |    std                | 1          |
# |    value_loss         | 0.000389   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47.5      |
# |    ep_rew_mean        | -47.5     |
# |    success_rate       | 0.05      |
# | time/                 |           |
# |    fps                | 318       |
# |    iterations         | 5100      |
# |    time_elapsed       | 512       |
# |    total_timesteps    | 163200    |
# | train/                |           |
# |    entropy_loss       | -12.9     |
# |    explained_variance | 0.8675559 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 0.154     |
# |    std                | 1.01      |
# |    value_loss         | 0.000352  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48         |
# |    ep_rew_mean        | -48        |
# |    success_rate       | 0.04       |
# | time/                 |            |
# |    fps                | 318        |
# |    iterations         | 5200       |
# |    time_elapsed       | 522        |
# |    total_timesteps    | 166400     |
# | train/                |            |
# |    entropy_loss       | -13        |
# |    explained_variance | 0.81046224 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5199       |
# |    policy_loss        | 0.0821     |
# |    std                | 1.01       |
# |    value_loss         | 0.000121   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48         |
# |    ep_rew_mean        | -48        |
# |    success_rate       | 0.04       |
# | time/                 |            |
# |    fps                | 318        |
# |    iterations         | 5300       |
# |    time_elapsed       | 533        |
# |    total_timesteps    | 169600     |
# | train/                |            |
# |    entropy_loss       | -12.9      |
# |    explained_variance | 0.14634567 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5299       |
# |    policy_loss        | -0.248     |
# |    std                | 1.01       |
# |    value_loss         | 0.0015     |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.3       |
# |    ep_rew_mean        | -48.2      |
# |    success_rate       | 0.04       |
# | time/                 |            |
# |    fps                | 318        |
# |    iterations         | 5400       |
# |    time_elapsed       | 542        |
# |    total_timesteps    | 172800     |
# | train/                |            |
# |    entropy_loss       | -13.2      |
# |    explained_variance | 0.16161984 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | -0.202     |
# |    std                | 1.01       |
# |    value_loss         | 0.00132    |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.7     |
# |    ep_rew_mean        | -46.6    |
# |    success_rate       | 0.07     |
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 5500     |
# |    time_elapsed       | 552      |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -13.1    |
# |    explained_variance | 0.511192 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.172   |
# |    std                | 1.01     |
# |    value_loss         | 0.000275 |
# ------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 47.5       |
# |    ep_rew_mean        | -47.5      |
# |    success_rate       | 0.05       |
# | time/                 |            |
# |    fps                | 318        |
# |    iterations         | 5600       |
# |    time_elapsed       | 562        |
# |    total_timesteps    | 179200     |
# | train/                |            |
# |    entropy_loss       | -13.1      |
# |    explained_variance | 0.91084754 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5599       |
# |    policy_loss        | -0.416     |
# |    std                | 1.01       |
# |    value_loss         | 0.000217   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 47.1       |
# |    ep_rew_mean        | -47        |
# |    success_rate       | 0.06       |
# | time/                 |            |
# |    fps                | 318        |
# |    iterations         | 5700       |
# |    time_elapsed       | 572        |
# |    total_timesteps    | 182400     |
# | train/                |            |
# |    entropy_loss       | -12.9      |
# |    explained_variance | 0.16224909 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | 0.64       |
# |    std                | 1.01       |
# |    value_loss         | 0.00031    |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 48.5        |
# |    ep_rew_mean        | -48.5       |
# |    success_rate       | 0.03        |
# | time/                 |             |
# |    fps                | 318         |
# |    iterations         | 5800        |
# |    time_elapsed       | 582         |
# |    total_timesteps    | 185600      |
# | train/                |             |
# |    entropy_loss       | -13.1       |
# |    explained_variance | -0.08413863 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5799        |
# |    policy_loss        | 0.472       |
# |    std                | 1.02        |
# |    value_loss         | 0.000149    |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.5       |
# |    ep_rew_mean        | -48.5      |
# |    success_rate       | 0.03       |
# | time/                 |            |
# |    fps                | 318        |
# |    iterations         | 5900       |
# |    time_elapsed       | 593        |
# |    total_timesteps    | 188800     |
# | train/                |            |
# |    entropy_loss       | -12.9      |
# |    explained_variance | 0.78302336 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5899       |
# |    policy_loss        | -0.173     |
# |    std                | 1.02       |
# |    value_loss         | 8.12e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.5       |
# |    ep_rew_mean        | -48.5      |
# |    success_rate       | 0.03       |
# | time/                 |            |
# |    fps                | 317        |
# |    iterations         | 6000       |
# |    time_elapsed       | 604        |
# |    total_timesteps    | 192000     |
# | train/                |            |
# |    entropy_loss       | -13        |
# |    explained_variance | 0.74731916 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | -0.15      |
# |    std                | 1.02       |
# |    value_loss         | 0.000178   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 49.5      |
# |    ep_rew_mean        | -49.5     |
# |    success_rate       | 0.01      |
# | time/                 |           |
# |    fps                | 317       |
# |    iterations         | 6100      |
# |    time_elapsed       | 614       |
# |    total_timesteps    | 195200    |
# | train/                |           |
# |    entropy_loss       | -13       |
# |    explained_variance | 0.6652093 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -0.761    |
# |    std                | 1.02      |
# |    value_loss         | 0.000227  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 49.5      |
# |    ep_rew_mean        | -49.5     |
# |    success_rate       | 0.01      |
# | time/                 |           |
# |    fps                | 317       |
# |    iterations         | 6200      |
# |    time_elapsed       | 625       |
# |    total_timesteps    | 198400    |
# | train/                |           |
# |    entropy_loss       | -13.3     |
# |    explained_variance | 0.9316036 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -0.296    |
# |    std                | 1.03      |
# |    value_loss         | 5.45e-05  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 47.6       |
# |    ep_rew_mean        | -47.6      |
# |    success_rate       | 0.05       |
# | time/                 |            |
# |    fps                | 316        |
# |    iterations         | 6300       |
# |    time_elapsed       | 636        |
# |    total_timesteps    | 201600     |
# | train/                |            |
# |    entropy_loss       | -13.4      |
# |    explained_variance | 0.93607414 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6299       |
# |    policy_loss        | -0.214     |
# |    std                | 1.03       |
# |    value_loss         | 5.07e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.6       |
# |    ep_rew_mean        | -48.6      |
# |    success_rate       | 0.03       |
# | time/                 |            |
# |    fps                | 316        |
# |    iterations         | 6400       |
# |    time_elapsed       | 646        |
# |    total_timesteps    | 204800     |
# | train/                |            |
# |    entropy_loss       | -13        |
# |    explained_variance | 0.40239954 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6399       |
# |    policy_loss        | 0.0409     |
# |    std                | 1.03       |
# |    value_loss         | 0.0058     |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 49.6       |
# |    ep_rew_mean        | -49.5      |
# |    success_rate       | 0.01       |
# | time/                 |            |
# |    fps                | 317        |
# |    iterations         | 6500       |
# |    time_elapsed       | 655        |
# |    total_timesteps    | 208000     |
# | train/                |            |
# |    entropy_loss       | -13.2      |
# |    explained_variance | 0.85146093 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | 0.246      |
# |    std                | 1.03       |
# |    value_loss         | 0.000494   |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.1     |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 6600     |
# |    time_elapsed       | 666      |
# |    total_timesteps    | 211200   |
# | train/                |          |
# |    entropy_loss       | -13.2    |
# |    explained_variance | 0.511835 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.472    |
# |    std                | 1.04     |
# |    value_loss         | 0.000284 |
# ------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 48.5        |
# |    ep_rew_mean        | -48.5       |
# |    success_rate       | 0.03        |
# | time/                 |             |
# |    fps                | 317         |
# |    iterations         | 6700        |
# |    time_elapsed       | 675         |
# |    total_timesteps    | 214400      |
# | train/                |             |
# |    entropy_loss       | -12.9       |
# |    explained_variance | 0.040961564 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6699        |
# |    policy_loss        | 0.0368      |
# |    std                | 1.03        |
# |    value_loss         | 0.000116    |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.5       |
# |    ep_rew_mean        | -48.5      |
# |    success_rate       | 0.03       |
# | time/                 |            |
# |    fps                | 317        |
# |    iterations         | 6800       |
# |    time_elapsed       | 684        |
# |    total_timesteps    | 217600     |
# | train/                |            |
# |    entropy_loss       | -13.1      |
# |    explained_variance | 0.81232464 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | 0.251      |
# |    std                | 1.03       |
# |    value_loss         | 8.71e-05   |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 6900     |
# |    time_elapsed       | 694      |
# |    total_timesteps    | 220800   |
# | train/                |          |
# |    entropy_loss       | -13.2    |
# |    explained_variance | 0.554294 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.312    |
# |    std                | 1.03     |
# |    value_loss         | 0.000703 |
# ------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48         |
# |    ep_rew_mean        | -48        |
# |    success_rate       | 0.04       |
# | time/                 |            |
# |    fps                | 318        |
# |    iterations         | 7000       |
# |    time_elapsed       | 704        |
# |    total_timesteps    | 224000     |
# | train/                |            |
# |    entropy_loss       | -13.2      |
# |    explained_variance | 0.92324835 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | 0.221      |
# |    std                | 1.03       |
# |    value_loss         | 0.000228   |
# --------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 47.1         |
# |    ep_rew_mean        | -47          |
# |    success_rate       | 0.06         |
# | time/                 |              |
# |    fps                | 318          |
# |    iterations         | 7100         |
# |    time_elapsed       | 713          |
# |    total_timesteps    | 227200       |
# | train/                |              |
# |    entropy_loss       | -13          |
# |    explained_variance | -0.069509864 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 7099         |
# |    policy_loss        | 0.432        |
# |    std                | 1.04         |
# |    value_loss         | 0.000287     |
# ----------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 46.6       |
# |    ep_rew_mean        | -46.5      |
# |    success_rate       | 0.07       |
# | time/                 |            |
# |    fps                | 318        |
# |    iterations         | 7200       |
# |    time_elapsed       | 723        |
# |    total_timesteps    | 230400     |
# | train/                |            |
# |    entropy_loss       | -13.2      |
# |    explained_variance | 0.07847518 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7199       |
# |    policy_loss        | -0.458     |
# |    std                | 1.03       |
# |    value_loss         | 0.00055    |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.5       |
# |    ep_rew_mean        | -48.5      |
# |    success_rate       | 0.03       |
# | time/                 |            |
# |    fps                | 319        |
# |    iterations         | 7300       |
# |    time_elapsed       | 731        |
# |    total_timesteps    | 233600     |
# | train/                |            |
# |    entropy_loss       | -13.2      |
# |    explained_variance | 0.72103095 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7299       |
# |    policy_loss        | 0.106      |
# |    std                | 1.03       |
# |    value_loss         | 7.78e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.5       |
# |    ep_rew_mean        | -48.5      |
# |    success_rate       | 0.03       |
# | time/                 |            |
# |    fps                | 319        |
# |    iterations         | 7400       |
# |    time_elapsed       | 741        |
# |    total_timesteps    | 236800     |
# | train/                |            |
# |    entropy_loss       | -13.2      |
# |    explained_variance | -1.6918397 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | -0.147     |
# |    std                | 1.03       |
# |    value_loss         | 0.00307    |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48         |
# |    ep_rew_mean        | -48        |
# |    success_rate       | 0.04       |
# | time/                 |            |
# |    fps                | 319        |
# |    iterations         | 7500       |
# |    time_elapsed       | 751        |
# |    total_timesteps    | 240000     |
# | train/                |            |
# |    entropy_loss       | -13.2      |
# |    explained_variance | 0.69863605 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | -0.355     |
# |    std                | 1.03       |
# |    value_loss         | 8.91e-05   |
# --------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 48.5         |
# |    ep_rew_mean        | -48.5        |
# |    success_rate       | 0.03         |
# | time/                 |              |
# |    fps                | 319          |
# |    iterations         | 7600         |
# |    time_elapsed       | 760          |
# |    total_timesteps    | 243200       |
# | train/                |              |
# |    entropy_loss       | -13.1        |
# |    explained_variance | -0.081160665 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 7599         |
# |    policy_loss        | 0.326        |
# |    std                | 1.04         |
# |    value_loss         | 0.000214     |
# ----------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 46.2      |
# |    ep_rew_mean        | -46.1     |
# |    success_rate       | 0.08      |
# | time/                 |           |
# |    fps                | 319       |
# |    iterations         | 7700      |
# |    time_elapsed       | 770       |
# |    total_timesteps    | 246400    |
# | train/                |           |
# |    entropy_loss       | -13.2     |
# |    explained_variance | 0.7319395 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | 0.21      |
# |    std                | 1.04      |
# |    value_loss         | 0.000974  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 46.8      |
# |    ep_rew_mean        | -46.7     |
# |    success_rate       | 0.07      |
# | time/                 |           |
# |    fps                | 319       |
# |    iterations         | 7800      |
# |    time_elapsed       | 781       |
# |    total_timesteps    | 249600    |
# | train/                |           |
# |    entropy_loss       | -13.2     |
# |    explained_variance | 0.7950616 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | -0.00434  |
# |    std                | 1.04      |
# |    value_loss         | 0.000147  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 49         |
# |    ep_rew_mean        | -49        |
# |    success_rate       | 0.02       |
# | time/                 |            |
# |    fps                | 319        |
# |    iterations         | 7900       |
# |    time_elapsed       | 790        |
# |    total_timesteps    | 252800     |
# | train/                |            |
# |    entropy_loss       | -13.4      |
# |    explained_variance | 0.65346193 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7899       |
# |    policy_loss        | 0.279      |
# |    std                | 1.04       |
# |    value_loss         | 0.000148   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 49.5       |
# |    ep_rew_mean        | -49.5      |
# |    success_rate       | 0.01       |
# | time/                 |            |
# |    fps                | 319        |
# |    iterations         | 8000       |
# |    time_elapsed       | 800        |
# |    total_timesteps    | 256000     |
# | train/                |            |
# |    entropy_loss       | -13.2      |
# |    explained_variance | 0.82492304 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | -0.0802    |
# |    std                | 1.04       |
# |    value_loss         | 5.08e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 49        |
# |    ep_rew_mean        | -49       |
# |    success_rate       | 0.02      |
# | time/                 |           |
# |    fps                | 319       |
# |    iterations         | 8100      |
# |    time_elapsed       | 810       |
# |    total_timesteps    | 259200    |
# | train/                |           |
# |    entropy_loss       | -13.3     |
# |    explained_variance | 0.6815083 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | -0.251    |
# |    std                | 1.04      |
# |    value_loss         | 0.000389  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.6     |
# |    ep_rew_mean        | -48.6    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 320      |
# |    iterations         | 8200     |
# |    time_elapsed       | 819      |
# |    total_timesteps    | 262400   |
# | train/                |          |
# |    entropy_loss       | -13.4    |
# |    explained_variance | 0.884956 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | -0.147   |
# |    std                | 1.03     |
# |    value_loss         | 7.33e-05 |
# ------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.6       |
# |    ep_rew_mean        | -48.6      |
# |    success_rate       | 0.03       |
# | time/                 |            |
# |    fps                | 320        |
# |    iterations         | 8300       |
# |    time_elapsed       | 828        |
# |    total_timesteps    | 265600     |
# | train/                |            |
# |    entropy_loss       | -13.3      |
# |    explained_variance | 0.60093033 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | 0.348      |
# |    std                | 1.04       |
# |    value_loss         | 0.000134   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47.5      |
# |    ep_rew_mean        | -47.5     |
# |    success_rate       | 0.05      |
# | time/                 |           |
# |    fps                | 320       |
# |    iterations         | 8400      |
# |    time_elapsed       | 838       |
# |    total_timesteps    | 268800    |
# | train/                |           |
# |    entropy_loss       | -13.5     |
# |    explained_variance | 0.7695402 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | 0.169     |
# |    std                | 1.04      |
# |    value_loss         | 0.000275  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 46.1       |
# |    ep_rew_mean        | -46        |
# |    success_rate       | 0.08       |
# | time/                 |            |
# |    fps                | 321        |
# |    iterations         | 8500       |
# |    time_elapsed       | 847        |
# |    total_timesteps    | 272000     |
# | train/                |            |
# |    entropy_loss       | -13.4      |
# |    explained_variance | 0.97425926 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8499       |
# |    policy_loss        | -0.398     |
# |    std                | 1.04       |
# |    value_loss         | 0.000309   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 47.5       |
# |    ep_rew_mean        | -47.5      |
# |    success_rate       | 0.05       |
# | time/                 |            |
# |    fps                | 321        |
# |    iterations         | 8600       |
# |    time_elapsed       | 856        |
# |    total_timesteps    | 275200     |
# | train/                |            |
# |    entropy_loss       | -13.2      |
# |    explained_variance | 0.32395953 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | -0.394     |
# |    std                | 1.04       |
# |    value_loss         | 0.000112   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47.5      |
# |    ep_rew_mean        | -47.5     |
# |    success_rate       | 0.05      |
# | time/                 |           |
# |    fps                | 321       |
# |    iterations         | 8700      |
# |    time_elapsed       | 867       |
# |    total_timesteps    | 278400    |
# | train/                |           |
# |    entropy_loss       | -13.3     |
# |    explained_variance | 0.9362521 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -0.159    |
# |    std                | 1.04      |
# |    value_loss         | 0.000127  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48        |
# |    ep_rew_mean        | -48       |
# |    success_rate       | 0.04      |
# | time/                 |           |
# |    fps                | 321       |
# |    iterations         | 8800      |
# |    time_elapsed       | 875       |
# |    total_timesteps    | 281600    |
# | train/                |           |
# |    entropy_loss       | -13.4     |
# |    explained_variance | -5.091527 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -0.129    |
# |    std                | 1.04      |
# |    value_loss         | 0.000419  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 47.5       |
# |    ep_rew_mean        | -47.5      |
# |    success_rate       | 0.05       |
# | time/                 |            |
# |    fps                | 321        |
# |    iterations         | 8900       |
# |    time_elapsed       | 885        |
# |    total_timesteps    | 284800     |
# | train/                |            |
# |    entropy_loss       | -13.4      |
# |    explained_variance | 0.88301694 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8899       |
# |    policy_loss        | -0.00528   |
# |    std                | 1.04       |
# |    value_loss         | 0.000104   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48.5      |
# |    ep_rew_mean        | -48.5     |
# |    success_rate       | 0.03      |
# | time/                 |           |
# |    fps                | 321       |
# |    iterations         | 9000      |
# |    time_elapsed       | 895       |
# |    total_timesteps    | 288000    |
# | train/                |           |
# |    entropy_loss       | -13.2     |
# |    explained_variance | 0.9003386 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | -0.318    |
# |    std                | 1.04      |
# |    value_loss         | 0.00269   |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.5       |
# |    ep_rew_mean        | -48.5      |
# |    success_rate       | 0.03       |
# | time/                 |            |
# |    fps                | 322        |
# |    iterations         | 9100       |
# |    time_elapsed       | 904        |
# |    total_timesteps    | 291200     |
# | train/                |            |
# |    entropy_loss       | -13.3      |
# |    explained_variance | 0.84691507 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9099       |
# |    policy_loss        | 0.705      |
# |    std                | 1.05       |
# |    value_loss         | 0.000194   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48.5      |
# |    ep_rew_mean        | -48.5     |
# |    success_rate       | 0.03      |
# | time/                 |           |
# |    fps                | 321       |
# |    iterations         | 9200      |
# |    time_elapsed       | 914       |
# |    total_timesteps    | 294400    |
# | train/                |           |
# |    entropy_loss       | -13.6     |
# |    explained_variance | 0.7012379 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9199      |
# |    policy_loss        | -0.209    |
# |    std                | 1.05      |
# |    value_loss         | 9.68e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -50      |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 321      |
# |    iterations         | 9300     |
# |    time_elapsed       | 924      |
# |    total_timesteps    | 297600   |
# | train/                |          |
# |    entropy_loss       | -13.6    |
# |    explained_variance | 0.772109 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9299     |
# |    policy_loss        | -0.826   |
# |    std                | 1.05     |
# |    value_loss         | 7.45e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 49        |
# |    ep_rew_mean        | -49       |
# |    success_rate       | 0.02      |
# | time/                 |           |
# |    fps                | 322       |
# |    iterations         | 9400      |
# |    time_elapsed       | 932       |
# |    total_timesteps    | 300800    |
# | train/                |           |
# |    entropy_loss       | -13.4     |
# |    explained_variance | 0.9647914 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9399      |
# |    policy_loss        | -0.389    |
# |    std                | 1.05      |
# |    value_loss         | 0.000341  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 49         |
# |    ep_rew_mean        | -49        |
# |    success_rate       | 0.02       |
# | time/                 |            |
# |    fps                | 322        |
# |    iterations         | 9500       |
# |    time_elapsed       | 942        |
# |    total_timesteps    | 304000     |
# | train/                |            |
# |    entropy_loss       | -13.5      |
# |    explained_variance | 0.26800346 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9499       |
# |    policy_loss        | 0.743      |
# |    std                | 1.06       |
# |    value_loss         | 7.52e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 49.5      |
# |    ep_rew_mean        | -49.5     |
# |    success_rate       | 0.01      |
# | time/                 |           |
# |    fps                | 322       |
# |    iterations         | 9600      |
# |    time_elapsed       | 952       |
# |    total_timesteps    | 307200    |
# | train/                |           |
# |    entropy_loss       | -13.6     |
# |    explained_variance | 0.7993444 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9599      |
# |    policy_loss        | -0.191    |
# |    std                | 1.06      |
# |    value_loss         | 5.91e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48.1      |
# |    ep_rew_mean        | -48.1     |
# |    success_rate       | 0.04      |
# | time/                 |           |
# |    fps                | 322       |
# |    iterations         | 9700      |
# |    time_elapsed       | 961       |
# |    total_timesteps    | 310400    |
# | train/                |           |
# |    entropy_loss       | -13.7     |
# |    explained_variance | 0.8851974 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9699      |
# |    policy_loss        | 0.0824    |
# |    std                | 1.06      |
# |    value_loss         | 0.00105   |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 47.7       |
# |    ep_rew_mean        | -47.6      |
# |    success_rate       | 0.05       |
# | time/                 |            |
# |    fps                | 322        |
# |    iterations         | 9800       |
# |    time_elapsed       | 971        |
# |    total_timesteps    | 313600     |
# | train/                |            |
# |    entropy_loss       | -13.4      |
# |    explained_variance | 0.80511844 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9799       |
# |    policy_loss        | -0.173     |
# |    std                | 1.06       |
# |    value_loss         | 3.23e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48        |
# |    ep_rew_mean        | -48       |
# |    success_rate       | 0.04      |
# | time/                 |           |
# |    fps                | 322       |
# |    iterations         | 9900      |
# |    time_elapsed       | 981       |
# |    total_timesteps    | 316800    |
# | train/                |           |
# |    entropy_loss       | -13.8     |
# |    explained_variance | 0.8528544 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | 0.0116    |
# |    std                | 1.06      |
# |    value_loss         | 3.21e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 50        |
# |    ep_rew_mean        | -50       |
# |    success_rate       | 0         |
# | time/                 |           |
# |    fps                | 323       |
# |    iterations         | 10000     |
# |    time_elapsed       | 989       |
# |    total_timesteps    | 320000    |
# | train/                |           |
# |    entropy_loss       | -13.5     |
# |    explained_variance | 0.9749564 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | 0.323     |
# |    std                | 1.06      |
# |    value_loss         | 3.12e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47.5      |
# |    ep_rew_mean        | -47.5     |
# |    success_rate       | 0.05      |
# | time/                 |           |
# |    fps                | 323       |
# |    iterations         | 10100     |
# |    time_elapsed       | 999       |
# |    total_timesteps    | 323200    |
# | train/                |           |
# |    entropy_loss       | -13.5     |
# |    explained_variance | 0.8134921 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 10099     |
# |    policy_loss        | -0.0905   |
# |    std                | 1.06      |
# |    value_loss         | 0.000131  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 47.5       |
# |    ep_rew_mean        | -47.5      |
# |    success_rate       | 0.05       |
# | time/                 |            |
# |    fps                | 323        |
# |    iterations         | 10200      |
# |    time_elapsed       | 1009       |
# |    total_timesteps    | 326400     |
# | train/                |            |
# |    entropy_loss       | -13.6      |
# |    explained_variance | 0.88097507 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 10199      |
# |    policy_loss        | 0.0349     |
# |    std                | 1.06       |
# |    value_loss         | 0.000398   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47.6      |
# |    ep_rew_mean        | -47.6     |
# |    success_rate       | 0.05      |
# | time/                 |           |
# |    fps                | 323       |
# |    iterations         | 10300     |
# |    time_elapsed       | 1018      |
# |    total_timesteps    | 329600    |
# | train/                |           |
# |    entropy_loss       | -13.3     |
# |    explained_variance | 0.7340739 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 10299     |
# |    policy_loss        | 0.0683    |
# |    std                | 1.06      |
# |    value_loss         | 0.000363  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 49.1      |
# |    ep_rew_mean        | -49.1     |
# |    success_rate       | 0.02      |
# | time/                 |           |
# |    fps                | 323       |
# |    iterations         | 10400     |
# |    time_elapsed       | 1028      |
# |    total_timesteps    | 332800    |
# | train/                |           |
# |    entropy_loss       | -13.6     |
# |    explained_variance | 0.9326229 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 10399     |
# |    policy_loss        | 0.046     |
# |    std                | 1.06      |
# |    value_loss         | 0.000198  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47.6      |
# |    ep_rew_mean        | -47.6     |
# |    success_rate       | 0.05      |
# | time/                 |           |
# |    fps                | 323       |
# |    iterations         | 10500     |
# |    time_elapsed       | 1037      |
# |    total_timesteps    | 336000    |
# | train/                |           |
# |    entropy_loss       | -13.6     |
# |    explained_variance | 0.8396069 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 10499     |
# |    policy_loss        | 0.0771    |
# |    std                | 1.07      |
# |    value_loss         | 0.000145  |
# -------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 48.5        |
# |    ep_rew_mean        | -48.5       |
# |    success_rate       | 0.03        |
# | time/                 |             |
# |    fps                | 324         |
# |    iterations         | 10600       |
# |    time_elapsed       | 1046        |
# |    total_timesteps    | 339200      |
# | train/                |             |
# |    entropy_loss       | -13.6       |
# |    explained_variance | -0.09065342 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 10599       |
# |    policy_loss        | 0.339       |
# |    std                | 1.06        |
# |    value_loss         | 7.53e-05    |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 48          |
# |    ep_rew_mean        | -48         |
# |    success_rate       | 0.04        |
# | time/                 |             |
# |    fps                | 323         |
# |    iterations         | 10700       |
# |    time_elapsed       | 1057        |
# |    total_timesteps    | 342400      |
# | train/                |             |
# |    entropy_loss       | -13.6       |
# |    explained_variance | -0.17448187 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 10699       |
# |    policy_loss        | 0.15        |
# |    std                | 1.06        |
# |    value_loss         | 2.76e-05    |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.5       |
# |    ep_rew_mean        | -48.5      |
# |    success_rate       | 0.03       |
# | time/                 |            |
# |    fps                | 324        |
# |    iterations         | 10800      |
# |    time_elapsed       | 1066       |
# |    total_timesteps    | 345600     |
# | train/                |            |
# |    entropy_loss       | -13.6      |
# |    explained_variance | 0.20483154 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 10799      |
# |    policy_loss        | -0.231     |
# |    std                | 1.06       |
# |    value_loss         | 0.000225   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 47.5       |
# |    ep_rew_mean        | -47.5      |
# |    success_rate       | 0.05       |
# | time/                 |            |
# |    fps                | 324        |
# |    iterations         | 10900      |
# |    time_elapsed       | 1075       |
# |    total_timesteps    | 348800     |
# | train/                |            |
# |    entropy_loss       | -13.4      |
# |    explained_variance | 0.42873156 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 10899      |
# |    policy_loss        | -0.254     |
# |    std                | 1.07       |
# |    value_loss         | 9.58e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 49.5       |
# |    ep_rew_mean        | -49.5      |
# |    success_rate       | 0.01       |
# | time/                 |            |
# |    fps                | 324        |
# |    iterations         | 11000      |
# |    time_elapsed       | 1085       |
# |    total_timesteps    | 352000     |
# | train/                |            |
# |    entropy_loss       | -13.6      |
# |    explained_variance | 0.80970407 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 10999      |
# |    policy_loss        | 0.038      |
# |    std                | 1.07       |
# |    value_loss         | 2.4e-05    |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 49        |
# |    ep_rew_mean        | -49       |
# |    success_rate       | 0.02      |
# | time/                 |           |
# |    fps                | 324       |
# |    iterations         | 11100     |
# |    time_elapsed       | 1095      |
# |    total_timesteps    | 355200    |
# | train/                |           |
# |    entropy_loss       | -13.6     |
# |    explained_variance | 0.8866569 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 11099     |
# |    policy_loss        | 0.138     |
# |    std                | 1.06      |
# |    value_loss         | 0.000246  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 45.6       |
# |    ep_rew_mean        | -45.6      |
# |    success_rate       | 0.09       |
# | time/                 |            |
# |    fps                | 324        |
# |    iterations         | 11200      |
# |    time_elapsed       | 1104       |
# |    total_timesteps    | 358400     |
# | train/                |            |
# |    entropy_loss       | -13.5      |
# |    explained_variance | 0.82609165 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 11199      |
# |    policy_loss        | 0.275      |
# |    std                | 1.06       |
# |    value_loss         | 0.000256   |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 47.5        |
# |    ep_rew_mean        | -47.5       |
# |    success_rate       | 0.05        |
# | time/                 |             |
# |    fps                | 324         |
# |    iterations         | 11300       |
# |    time_elapsed       | 1114        |
# |    total_timesteps    | 361600      |
# | train/                |             |
# |    entropy_loss       | -13.6       |
# |    explained_variance | 0.120401025 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 11299       |
# |    policy_loss        | -0.247      |
# |    std                | 1.06        |
# |    value_loss         | 0.087       |
# ---------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47.5      |
# |    ep_rew_mean        | -47.5     |
# |    success_rate       | 0.05      |
# | time/                 |           |
# |    fps                | 324       |
# |    iterations         | 11400     |
# |    time_elapsed       | 1123      |
# |    total_timesteps    | 364800    |
# | train/                |           |
# |    entropy_loss       | -13.5     |
# ...
# |    success_rate       | 0.05      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 29100     |
# |    time_elapsed       | 2855      |
# |    total_timesteps    | 931200    |
# | train/                |           |
# |    entropy_loss       | -13.6     |
# |    explained_variance | 0.6589513 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29099     |
# |    policy_loss        | -0.263    |
# |    std                | 1.04      |
# |    value_loss         | 0.000303  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 49         |
# |    ep_rew_mean        | -49        |
# |    success_rate       | 0.02       |
# | time/                 |            |
# |    fps                | 326        |
# |    iterations         | 29200      |
# |    time_elapsed       | 2865       |
# |    total_timesteps    | 934400     |
# | train/                |            |
# |    entropy_loss       | -13.7      |
# |    explained_variance | 0.74887574 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 29199      |
# |    policy_loss        | -0.468     |
# |    std                | 1.04       |
# |    value_loss         | 0.000352   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48.5      |
# |    ep_rew_mean        | -48.5     |
# |    success_rate       | 0.03      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 29300     |
# |    time_elapsed       | 2873      |
# |    total_timesteps    | 937600    |
# | train/                |           |
# |    entropy_loss       | -13.6     |
# |    explained_variance | 0.4182592 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29299     |
# |    policy_loss        | 0.181     |
# |    std                | 1.04      |
# |    value_loss         | 0.00192   |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.1       |
# |    ep_rew_mean        | -48        |
# |    success_rate       | 0.04       |
# | time/                 |            |
# |    fps                | 326        |
# |    iterations         | 29400      |
# |    time_elapsed       | 2884       |
# |    total_timesteps    | 940800     |
# | train/                |            |
# |    entropy_loss       | -13.6      |
# |    explained_variance | -4.9874616 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 29399      |
# |    policy_loss        | 0.253      |
# |    std                | 1.03       |
# |    value_loss         | 0.00175    |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48.1      |
# |    ep_rew_mean        | -48       |
# |    success_rate       | 0.04      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 29500     |
# |    time_elapsed       | 2894      |
# |    total_timesteps    | 944000    |
# | train/                |           |
# |    entropy_loss       | -13.7     |
# |    explained_variance | 0.5246644 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29499     |
# |    policy_loss        | -0.101    |
# |    std                | 1.03      |
# |    value_loss         | 0.00015   |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 49         |
# |    ep_rew_mean        | -49        |
# |    success_rate       | 0.02       |
# | time/                 |            |
# |    fps                | 326        |
# |    iterations         | 29600      |
# |    time_elapsed       | 2903       |
# |    total_timesteps    | 947200     |
# | train/                |            |
# |    entropy_loss       | -13.6      |
# |    explained_variance | 0.69092906 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 29599      |
# |    policy_loss        | 0.205      |
# |    std                | 1.03       |
# |    value_loss         | 0.000331   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 49.5      |
# |    ep_rew_mean        | -49.5     |
# |    success_rate       | 0.01      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 29700     |
# |    time_elapsed       | 2914      |
# |    total_timesteps    | 950400    |
# | train/                |           |
# |    entropy_loss       | -13.8     |
# |    explained_variance | 0.2750659 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29699     |
# |    policy_loss        | -0.0643   |
# |    std                | 1.03      |
# |    value_loss         | 0.000148  |
# -------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 49          |
# |    ep_rew_mean        | -49         |
# |    success_rate       | 0.02        |
# | time/                 |             |
# |    fps                | 326         |
# |    iterations         | 29800       |
# |    time_elapsed       | 2924        |
# |    total_timesteps    | 953600      |
# | train/                |             |
# |    entropy_loss       | -13.6       |
# |    explained_variance | 0.068899035 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 29799       |
# |    policy_loss        | 0.0548      |
# |    std                | 1.03        |
# |    value_loss         | 0.000206    |
# ---------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 49           |
# |    ep_rew_mean        | -49          |
# |    success_rate       | 0.02         |
# | time/                 |              |
# |    fps                | 326          |
# |    iterations         | 29900        |
# |    time_elapsed       | 2933         |
# |    total_timesteps    | 956800       |
# | train/                |              |
# |    entropy_loss       | -13.7        |
# |    explained_variance | -0.035295844 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 29899        |
# |    policy_loss        | -0.0841      |
# |    std                | 1.03         |
# |    value_loss         | 0.000942     |
# ----------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 49        |
# |    ep_rew_mean        | -49       |
# |    success_rate       | 0.02      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 30000     |
# |    time_elapsed       | 2943      |
# |    total_timesteps    | 960000    |
# | train/                |           |
# |    entropy_loss       | -13.7     |
# |    explained_variance | 0.7877892 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 29999     |
# |    policy_loss        | -0.161    |
# |    std                | 1.03      |
# |    value_loss         | 8.62e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48        |
# |    ep_rew_mean        | -48       |
# |    success_rate       | 0.04      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 30100     |
# |    time_elapsed       | 2954      |
# |    total_timesteps    | 963200    |
# | train/                |           |
# |    entropy_loss       | -13.7     |
# |    explained_variance | 0.8193641 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 30099     |
# |    policy_loss        | 0.0714    |
# |    std                | 1.03      |
# |    value_loss         | 0.000828  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 47.9       |
# |    ep_rew_mean        | -47.8      |
# |    success_rate       | 0.05       |
# | time/                 |            |
# |    fps                | 326        |
# |    iterations         | 30200      |
# |    time_elapsed       | 2963       |
# |    total_timesteps    | 966400     |
# | train/                |            |
# |    entropy_loss       | -13.8      |
# |    explained_variance | 0.71456015 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 30199      |
# |    policy_loss        | 0.157      |
# |    std                | 1.04       |
# |    value_loss         | 0.00016    |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.4       |
# |    ep_rew_mean        | -48.3      |
# |    success_rate       | 0.04       |
# | time/                 |            |
# |    fps                | 326        |
# |    iterations         | 30300      |
# |    time_elapsed       | 2973       |
# |    total_timesteps    | 969600     |
# | train/                |            |
# |    entropy_loss       | -13.7      |
# |    explained_variance | -0.5824038 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 30299      |
# |    policy_loss        | 0.769      |
# |    std                | 1.04       |
# |    value_loss         | 0.000267   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 46.6       |
# |    ep_rew_mean        | -46.5      |
# |    success_rate       | 0.07       |
# | time/                 |            |
# |    fps                | 326        |
# |    iterations         | 30400      |
# |    time_elapsed       | 2983       |
# |    total_timesteps    | 972800     |
# | train/                |            |
# |    entropy_loss       | -13.7      |
# |    explained_variance | 0.88905126 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 30399      |
# |    policy_loss        | -0.167     |
# |    std                | 1.04       |
# |    value_loss         | 0.000281   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48        |
# |    ep_rew_mean        | -48       |
# |    success_rate       | 0.04      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 30500     |
# |    time_elapsed       | 2991      |
# |    total_timesteps    | 976000    |
# | train/                |           |
# |    entropy_loss       | -13.7     |
# |    explained_variance | 0.3752035 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 30499     |
# |    policy_loss        | -0.0317   |
# |    std                | 1.04      |
# |    value_loss         | 0.000223  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48.5      |
# |    ep_rew_mean        | -48.5     |
# |    success_rate       | 0.03      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 30600     |
# |    time_elapsed       | 3002      |
# |    total_timesteps    | 979200    |
# | train/                |           |
# |    entropy_loss       | -13.8     |
# |    explained_variance | 0.5217835 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 30599     |
# |    policy_loss        | -0.0869   |
# |    std                | 1.04      |
# |    value_loss         | 0.000166  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48.1       |
# |    ep_rew_mean        | -48.1      |
# |    success_rate       | 0.04       |
# | time/                 |            |
# |    fps                | 326        |
# |    iterations         | 30700      |
# |    time_elapsed       | 3012       |
# |    total_timesteps    | 982400     |
# | train/                |            |
# |    entropy_loss       | -13.8      |
# |    explained_variance | 0.07858384 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 30699      |
# |    policy_loss        | 0.35       |
# |    std                | 1.04       |
# |    value_loss         | 0.000298   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48.5      |
# |    ep_rew_mean        | -48.5     |
# |    success_rate       | 0.03      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 30800     |
# |    time_elapsed       | 3021      |
# |    total_timesteps    | 985600    |
# | train/                |           |
# |    entropy_loss       | -13.7     |
# |    explained_variance | -4.541257 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 30799     |
# |    policy_loss        | 0.145     |
# |    std                | 1.04      |
# |    value_loss         | 0.0018    |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 49.5       |
# |    ep_rew_mean        | -49.5      |
# |    success_rate       | 0.01       |
# | time/                 |            |
# |    fps                | 326        |
# |    iterations         | 30900      |
# |    time_elapsed       | 3031       |
# |    total_timesteps    | 988800     |
# | train/                |            |
# |    entropy_loss       | -13.9      |
# |    explained_variance | 0.90990084 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 30899      |
# |    policy_loss        | -0.305     |
# |    std                | 1.04       |
# |    value_loss         | 0.000132   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47.5      |
# |    ep_rew_mean        | -47.5     |
# |    success_rate       | 0.05      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 31000     |
# |    time_elapsed       | 3041      |
# |    total_timesteps    | 992000    |
# | train/                |           |
# |    entropy_loss       | -13.9     |
# |    explained_variance | 0.6972518 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 30999     |
# |    policy_loss        | 0.0236    |
# |    std                | 1.05      |
# |    value_loss         | 0.000175  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 48         |
# |    ep_rew_mean        | -48        |
# |    success_rate       | 0.04       |
# | time/                 |            |
# |    fps                | 326        |
# |    iterations         | 31100      |
# |    time_elapsed       | 3050       |
# |    total_timesteps    | 995200     |
# | train/                |            |
# |    entropy_loss       | -13.8      |
# |    explained_variance | 0.89132553 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 31099      |
# |    policy_loss        | -0.22      |
# |    std                | 1.04       |
# |    value_loss         | 6.82e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 48        |
# |    ep_rew_mean        | -48       |
# |    success_rate       | 0.04      |
# | time/                 |           |
# |    fps                | 326       |
# |    iterations         | 31200     |
# |    time_elapsed       | 3060      |
# |    total_timesteps    | 998400    |
# | train/                |           |
# |    entropy_loss       | -13.9     |
# |    explained_variance | 0.5876822 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 31199     |
# |    policy_loss        | 0.692     |
# |    std                | 1.04      |
# |    value_loss         | 0.000197  |
# -------------------------------------

# %%
# 6
model_name = "a2c-PandaPickAndPlace-v3_new";
model.save(model_name)
env.save("vec_normalize_a2c_PandaPickAndPlace_v3_new.pkl")

# %%
# Save the model to Drive

model.save("/content/drive/MyDrive/models/4_a2c-PandaPickAndPlace-v3")
env.save("/content/drive/MyDrive/models/4_vec_normalize_a2c_PandaPickAndPlace_v3.pkl")

# %%
# 6
# model_name = "a2c-PandaPickAndPlace-v3";
# model.save(model_name)
# env.save("vec_normalize_a2c_PandaPickAndPlace_v3.pkl")

# 7
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaPickAndPlace-v3")])
eval_env = VecNormalize.load("vec_normalize_a2c_PandaPickAndPlace_v3_new.pkl", eval_env)

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load(model_name)
mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")

# 8
package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"Htar/a2c-{env_id}-hyperparameters", # TODO: Change the username
    commit_message="Initial commit",
)
# Out:
# a2c-PandaPickAndPlace-v3_new
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward = -50.00 +/- 0.00
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Saving video to /tmp/tmpd6w1kxqa/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpd6w1kxqa/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpd6w1kxqa/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpd6w1kxqa/-step-0-to-step-1000.mp4
# ℹ Pushing repo Htar/a2c-PandaPickAndPlace-v3-hyperparameters to the
# Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:114: DeprecationWarning: hf_xet.upload_files() is deprecated. Use XetSession().new_upload_commit().start_upload_file() instead.
#   return fn(*args, **kwargs)
#   ...-v3/pytorch_variables.pth: 100%|##########| 1.26kB / 1.26kB
#   /tmp/tmpajlu6xow/replay.mp4 :  69%|######8   |  382kB /  555kB
#   ...e-v3/policy.optimizer.pth:  69%|######8   | 39.1kB / 56.9kB
#   ...jlu6xow/vec_normalize.pkl:  69%|######8   | 2.10kB / 3.05kB
#   ...ickAndPlace-v3/policy.pth:  69%|######8   | 37.6kB / 54.7kB
#   ...-PandaPickAndPlace-v3.zip:  69%|######8   | 91.9kB /  134kB
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Htar/a2c-PandaPickAndPlace-v3-hyperparameters/tree/main/
# CommitInfo(commit_url='https://huggingface.co/Htar/a2c-PandaPickAndPlace-v3-hyperparameters/commit/31cc6bc489b121c0758421631758ad722c26facf', commit_message='Initial commit', commit_description='', oid='31cc6bc489b121c0758421631758ad722c26facf', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Htar/a2c-PandaPickAndPlace-v3-hyperparameters', endpoint='https://huggingface.co', repo_type='model', repo_id='Htar/a2c-PandaPickAndPlace-v3-hyperparameters'), pr_revision=None, pr_num=None)

# %% [markdown]
# See you on Unit 7! 🔥
# ## Keep learning, stay awesome 🤗
